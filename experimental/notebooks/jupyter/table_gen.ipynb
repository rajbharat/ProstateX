# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
from pathlib import Path

# %%
images_train = pd.read_csv('../data/raw/train_labels/ProstateX-Images-Train.csv')
ktrans_train = pd.read_csv('../data/raw/train_labels/ProstateX-Images-KTrans-Train.csv')
findings_train = pd.read_csv('../data/raw/train_labels/ProstateX-Findings-Train.csv')

# %%
# The usual check for successful conversions
dicom2nifti_success = Path.cwd().parent / 'logs/dicom2nifti_successful.txt'
successful_conv = dicom2nifti_success.read_text()
successful_conv = successful_conv.split('\n')
successful_conv = list(filter(None, successful_conv)) # For sanity - remove any empty string(s)

# %% [markdown]
# ## Building dataframes for different sequences

# %%
root_dir = Path.cwd().parent
nifti = root_dir.joinpath('data/generated/nifti') 

def generate_df_for_sequence(sequence_type):
    """
    This function generates a dataframe for all patients in the dataset. Each row contains
    a string that is analgous to the DCMSerDescr label in the other train files. This string
    is generated from the original filename. The second column contains a path object for the 
    resampled nifti file. This table can be joined to the other training files to create one
    large table with the appropriate sampling information.
    """
    patient_data = {}
    patient_folders = [x for x in nifti.iterdir() if x.is_dir()]
    for patient in patient_folders:
        if patient.stem in successful_conv: 
            sequences = [x for x in patient.iterdir() if x.is_dir()]
            for sequence in sequences:
                if sequence.parts[-1] == sequence_type:
                    for item in sequence.rglob('*.*'):
                        
                        def generate_DCMSerDescr_from_filename():
                            # remove extension from path
                            full_name = item.parts[-1]
                            split = full_name.split('.') 
                            name_without_extension = split[0]

                            # remove first num and underscore from path
                            first_underscore = name_without_extension.find('_') + 1
                            value = name_without_extension[first_underscore:]
                            return value
                        
                        def get_path_to_resampled(sequence_type):
                            nifti_resampled = root_dir.joinpath('data/generated/nifti_resampled')
                            sequence_types = [x for x in nifti_resampled.iterdir() if x.is_dir()]
                            for sequence in sequence_types:
                                # check if directory name contains sequence type
                                if sequence_type in str(sequence):
                                    # then get all files in subdirectory
                                    files = sequence.rglob('*.*')          
                                    for file in files:
                                        # then check if filename contains patient_id
                                        if patient.parts[-1] in str(file): 
                                            path_to_resampled = file
                                            
                            return path_to_resampled
                        
                        DCMSerDescr_fn = generate_DCMSerDescr_from_filename()
                        path_to_resampled = get_path_to_resampled(sequence_type)
                        
                        key = patient.parts[-1] # patient_ID
                        value = [DCMSerDescr_fn, path_to_resampled]
                        patient_data[key] = value 
    
    data_frame = pd.DataFrame.from_dict(patient_data, orient = 'index')
    data_frame = data_frame.reset_index()
    data_frame.columns = ['ProxID','DCMSerDescr', 'path_to_resampled_file'] # renaming columns
    return data_frame

# %% [markdown]
# ## Generating joined dataframes for each sequence type

# %%
print('Images:', images_train.columns.values)
print('Ktrans:', ktrans_train.columns.values)
print('Findings:', findings_train.columns.values)
# Out:
# Images: ['ProxID' 'Name' 'fid' 'pos' 'WorldMatrix' 'ijk' 'TopLevel'
#  'SpacingBetweenSlices' 'VoxelSpacing' 'Dim' 'DCMSerDescr' 'DCMSerNum']
# Ktrans: ['ProxID' 'fid' 'pos' 'WorldMatrix' 'ijk']
# Findings: ['ProxID' 'fid' 'pos' 'zone' 'ClinSig']

# %%
def join_dataframes (sequence_df, images_train_df, findings_train_df):

    sequence_df.loc[:,'DCMSerDescr'] = sequence_df.loc[:,'DCMSerDescr'].apply(lambda x: x.lower())
    
    if 'DCMSerDescr' in list(images_train_df.columns.values):
        # Subset to desired columns only and lowercase
        images_train_df.loc[:,'DCMSerDescr'] = images_train_df.loc[:,'DCMSerDescr'].apply(lambda x: x.lower())
        images_train_df = images_train_df[['ProxID', 'DCMSerDescr', 'fid', 'pos', 'WorldMatrix', 'ijk']]
        
        first_merge = pd.merge(sequence_df, images_train_df, how = 'left', on = ['ProxID', 'DCMSerDescr'])    
        final_merge = pd.merge(first_merge, findings_train_df, how = 'left', on = ['ProxID', 'fid','pos'])
    else:
        first_merge = pd.merge(sequence_df, images_train_df, how = 'left', on = ['ProxID'])
        final_merge = pd.merge(first_merge, findings_train_df, how = 'left', on = ['ProxID', 'fid', 'pos'])

    return final_merge

# %%
t2_df = generate_df_for_sequence('t2')
adc_df = generate_df_for_sequence('adc')
bval_df = generate_df_for_sequence('bval')
ktrans_df = generate_df_for_sequence('ktrans')

# %%
t2_df_pe = join_dataframes(t2_df, images_train, findings_train)

# %%
adc_df_pe = join_dataframes(adc_df, images_train, findings_train)

# %%
bval_df_pe = join_dataframes(bval_df, images_train, findings_train)

# %%
ktrans_df_pe = join_dataframes(ktrans_df, ktrans_train, findings_train)

# %%
ktrans_df_pe
# Out:
#             ProxID            DCMSerDescr  \
# 0   ProstateX-0005  prostatex-0005-ktrans
# 1   ProstateX-0005  prostatex-0005-ktrans
# 2   ProstateX-0005  prostatex-0005-ktrans
# 3   ProstateX-0002  prostatex-0002-ktrans
# 4   ProstateX-0002  prostatex-0002-ktrans
# 5   ProstateX-0034  prostatex-0034-ktrans
# 6   ProstateX-0033  prostatex-0033-ktrans
# 7   ProstateX-0033  prostatex-0033-ktrans
# 8   ProstateX-0032  prostatex-0032-ktrans
# 9   ProstateX-0035  prostatex-0035-ktrans
# 10  ProstateX-0035  prostatex-0035-ktrans
# 11  ProstateX-0003  prostatex-0003-ktrans
# 12  ProstateX-0003  prostatex-0003-ktrans
# 13  ProstateX-0004  prostatex-0004-ktrans
# 14  ProstateX-0019  prostatex-0019-ktrans
# 15  ProstateX-0026  prostatex-0026-ktrans
# 16  ProstateX-0021  prostatex-0021-ktrans
# 17  ProstateX-0021  prostatex-0021-ktrans
# 18  ProstateX-0028  prostatex-0028-ktrans
# 19  ProstateX-0028  prostatex-0028-ktrans
# 20  ProstateX-0017  prostatex-0017-ktrans
# 21  ProstateX-0010  prostatex-0010-ktrans
# 22  ProstateX-0044  prostatex-0044-ktrans
# 23  ProstateX-0043  prostatex-0043-ktrans
# 24  ProstateX-0011  prostatex-0011-ktrans
# 25  ProstateX-0029  prostatex-0029-ktrans
# 26  ProstateX-0016  prostatex-0016-ktrans
# 27  ProstateX-0020  prostatex-0020-ktrans
# 28  ProstateX-0027  prostatex-0027-ktrans
# 29  ProstateX-0042  prostatex-0042-ktrans
# ..             ...                    ...
# 32  ProstateX-0006  prostatex-0006-ktrans
# 33  ProstateX-0039  prostatex-0039-ktrans
# 34  ProstateX-0030  prostatex-0030-ktrans
# 35  ProstateX-0037  prostatex-0037-ktrans
# 36  ProstateX-0037  prostatex-0037-ktrans
# 37  ProstateX-0008  prostatex-0008-ktrans
# 38  ProstateX-0009  prostatex-0009-ktrans
# 39  ProstateX-0031  prostatex-0031-ktrans
# 40  ProstateX-0031  prostatex-0031-ktrans
# 41  ProstateX-0007  prostatex-0007-ktrans
# 42  ProstateX-0038  prostatex-0038-ktrans
# 43  ProstateX-0038  prostatex-0038-ktrans
# 44  ProstateX-0038  prostatex-0038-ktrans
# 45  ProstateX-0000  prostatex-0000-ktrans
# 46  ProstateX-0040  prostatex-0040-ktrans
# 47  ProstateX-0040  prostatex-0040-ktrans
# 48  ProstateX-0040  prostatex-0040-ktrans
# 49  ProstateX-0047  prostatex-0047-ktrans
# 50  ProstateX-0049  prostatex-0049-ktrans
# 51  ProstateX-0022  prostatex-0022-ktrans
# 52  ProstateX-0013  prostatex-0013-ktrans
# 53  ProstateX-0014  prostatex-0014-ktrans
# 54  ProstateX-0048  prostatex-0048-ktrans
# 55  ProstateX-0046  prostatex-0046-ktrans
# 56  ProstateX-0046  prostatex-0046-ktrans
# 57  ProstateX-0041  prostatex-0041-ktrans
# 58  ProstateX-0015  prostatex-0015-ktrans
# 59  ProstateX-0024  prostatex-0024-ktrans
# 60  ProstateX-0023  prostatex-0023-ktrans
# 61  ProstateX-0023  prostatex-0023-ktrans
#
#                                path_to_resampled_file  fid  \
# 0   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    0
# 1   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 2   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 3   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 4   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 5   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 6   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 7   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    3
# 8   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 9   /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 10  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 11  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 12  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 13  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 14  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 15  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 16  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 17  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    4
# 18  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 19  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 20  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 21  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 22  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 23  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 24  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 25  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 26  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 27  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 28  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 29  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# ..                                                ...  ...
# 32  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 33  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 34  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 35  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 36  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 37  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 38  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 39  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 40  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 41  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 42  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 43  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 44  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    3
# 45  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 46  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 47  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 48  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    3
# 49  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 50  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 51  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 52  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 53  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 54  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 55  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 56  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
# 57  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 58  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 59  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 60  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    1
# 61  /Users/alexanders-13mbp/DataProjects/MBI/CISC_...    2
#
#                                                   pos  \
# 0   -14.5174331665039 49.4428329467773 20.78152465...
# 1   -22.0892639160156 25.4668045043945 22.87915420...
# 2                            -38.6276 42.2781 21.4084
# 3                           -27.0102 41.5467 -26.0469
# 4                             -2.058 38.6752 -34.6104
# 5                              17.0042 60.678 5.75149
# 6                           -0.473669 43.2903 35.9394
# 7                              24.7403 33.959 34.6019
# 8                             19.0001 60.9885 -32.157
# 9                           -22.9279 28.8785 -29.5951
# 10                           17.2049 16.7651 -24.8213
# 11                           22.1495 31.2717 -2.45933
# 12                           -21.2871 19.3995 19.7429
# 13                           -7.69665 3.64226 23.1659
# 14                          -4.21012 42.1916 -40.6457
# 15                          -2.55984 36.7959 -40.4785
# 16                             13.33 33.2901 -26.3378
# 17                           38.7099 28.8409 -28.6634
# 18                           32.6256 39.4066 -7.95307
# 19                           -9.64486 40.691 -5.07664
# 20                           2.89097 49.4408 -14.4697
# 21                           -31.8128 51.364 -56.0047
# 22                          -5.795073 18.7907 87.5082
# 23                           8.92826 59.9957 -1.69448
# 24                            9.29795 10.7009 14.2935
# 25                            -27.064 50.9487 19.5641
# 26                          -17.4648 10.7487 -1.55198
# 27                            10.1617 53.5994 10.0223
# 28                           -8.16043 63.437 -9.60785
# 29                           0.258727 12.1867 29.2257
# ..                                                ...
# 32                          -9.85971 37.2739 0.561445
# 33                            -29.2205 47.977 66.1721
# 34                           35.3287 44.3674 -50.6832
# 35         10.0109 21.7560412231445 0.489487200805664
# 36                           11.742 38.1655 0.0225723
# 37                            25.2302 38.6613 -26.864
# 38                            19.565 32.8037 -37.4421
# 39                            8.08436 38.9556 13.8648
# 40                           -25.5225 39.8319 13.5071
# 41                             -5.4258 20.1075 -57.34
# 42                            -35.8699 29.366 22.5239
# 43                            -2.27438 42.417 21.4611
# 44                            -34.7633 44.767 14.3969
# 45                            25.7457 31.8707 -38.511
# 46                             5.7972 19.5845 -58.366
# 47                             32.0217 37.5945 -70.54
# 48                           41.7562 24.6357 -74.4334
# 49                          -24.2868 62.7355 -24.2213
# 50                            27.5717 36.0367 8.92738
# 51                          -22.5143 51.5685 -107.645
# 52                           -42.7915 30.7382 5.60159
# 53                           -23.0672 31.7673 3.02353
# 54                           18.4772 48.0755 -83.6069
# 55                           -32.861 -2.20032 46.9729
# 56                           -4.84385 2.95186 35.0858
# 57                         -11.24582 60.9975 -48.0648
# 58                                    -3.5 -4.2 -40.5
# 59                          -19.4802 26.3731 -25.4612
# 60                           -4.543299 32.541 13.5624
# 61                            30.8291 20.0179 17.6021
#
#                                           WorldMatrix       ijk zone  ClinSig
# 0   1.5,3.07655e-010,1.10673e-016,-117.778,-3.0648...   69 78 8   PZ     True
# 1   1.5,3.07655e-010,1.10673e-016,-117.778,-3.0648...   64 62 8   TZ    False
# 2   1.5,3.07655e-010,1.10673e-016,-117.778,-3.0648...   53 73 8   PZ     True
# 3   1.5,3.07655e-010,7.98512e-017,-104.284,-2.9890...  52 73 11   PZ     True
# 4   1.5,3.07655e-010,7.98512e-017,-104.284,-2.9890...   68 72 8   PZ    False
# 5   1.5,3.07655e-010,-1.39642e-016,-85.0813,-2.963...  68 80 12   PZ    False
# 6   1.5,3.07655e-010,-5.59082e-018,-82.2922,-3.026...   55 75 6   PZ    False
# 7   1.5,3.07655e-010,-5.59082e-018,-82.2922,-3.026...   71 69 5   TZ    False
# 8   1.5,3.07655e-010,-1.1706e-016,-96.6499,-2.7557...  77 81 14   PZ    False
# 9   1.5,3.07655e-010,-7.29555e-017,-98.5005,-2.957...   50 66 7   AS     True
# 10  1.5,3.07655e-010,-7.29555e-017,-98.5005,-2.957...   77 57 7   TZ    False
# 11  1.5,3.07655e-010,3.75383e-017,-98.5005,-2.5684...  80 69 10   TZ    False
# 12  1.5,3.07655e-010,3.75383e-017,-98.5005,-2.5684...  51 54 13   TZ    False
# 13  1.5,3.07655e-010,7.04037e-017,-118.663,-2.9851...   74 56 6   AS    False
# 14  1.5,3.07655e-010,8.04246e-017,-95.6089,-2.9209...   61 79 9   PZ     True
# 15  1.5,3.07655e-010,-6.19441e-017,-90.7896,-3.057...   59 66 5   TZ     True
# 16  1.5,3.07655e-010,-1.15225e-016,-84.3696,-3.037...   65 63 7   TZ    False
# 17  1.5,3.07655e-010,-1.15225e-016,-84.3696,-3.037...   82 60 6   PZ    False
# 18  1.5,3.07655e-010,-6.19441e-017,-85.9704,-3.057...   79 70 6   PZ     True
# 19  1.5,3.07655e-010,-6.19441e-017,-85.9704,-3.057...   51 71 7   PZ    False
# 20  1.5,3.07655e-010,2.14428e-017,-98.5005,-2.8836...   68 78 8   PZ    False
# 21  1.5,3.07655e-010,8.29013e-018,-107.175,-2.9436...   50 71 9   PZ    False
# 22  1.5,3.07655e-010,-1.04732e-016,-105.247,-2.963...   66 60 4   PZ    False
# 23  1.5,3.07655e-010,-5.30542e-018,-73.4402,-2.912...  55 75 13   PZ    False
# 24  1.5,3.07655e-010,-1.08839e-016,-101.392,-3.076...   74 66 7   PZ    False
# 25  1.49721,-0.0313622,-0.228866,-129.909,0.040654...  72 78 10   PZ    False
# 26  1.5,3.07655e-010,6.68434e-017,-103.32,-3.00363...   57 57 4   AS    False
# 27  1.5,3.07655e-010,-3.85808e-017,-68.8908,-2.866...   53 77 7   PZ    False
# 28  1.5,3.07655e-010,-6.19441e-017,-88.8619,-3.057...   54 82 8   PZ    False
# 29  1.5,3.07655e-010,4.97305e-017,-105.247,-2.9325...   70 58 4   TZ    False
# ..                                                ...       ...  ...      ...
# 32  1.5,3.07655e-010,4.75306e-017,-103.32,-3.00128...  62 74 13   PZ    False
# 33  1.5,3.07655e-010,2.40734e-017,-98.5005,-2.9513...  46 75 10   PZ    False
# 34  1.5,3.07655e-010,4.73832e-017,-76.3318,-2.9758...  74 67 10   PZ    False
# 35  1.5,3.07655e-010,-7.89433e-017,-71.5125,-3.039...   54 63 7   AS     True
# 36  1.5,3.07655e-010,-7.89433e-017,-71.5125,-3.039...   56 74 6   PZ    False
# 37  1.5,3.07655e-010,2.09813e-016,-86.1336,-2.9952...   74 72 9   PZ    False
# 38  1.5,3.07655e-010,-6.19441e-017,-79.2284,-3.057...  66 64 11   TZ    False
# 39  1.5,3.07655e-010,9.22592e-017,-108.139,-2.8484...  77 69 11   PZ     True
# 40  1.5,3.07655e-010,9.22592e-017,-108.139,-2.8484...  55 70 11   PZ    False
# 41  1.5,3.07655e-010,-6.19441e-017,-112.375,-3.057...   71 61 5   TZ    False
# 42  1.5,3.07655e-010,1.73984e-017,-115.85,-2.92763...   53 63 9   TZ    False
# 43  1.5,3.07655e-010,1.73984e-017,-115.85,-2.92763...   76 71 9   PZ    False
# 44  1.5,3.07655e-010,1.73984e-017,-115.85,-2.92763...   54 74 8   PZ    False
# 45  1.5,3.00503e-010,0.00377059,-58.4317,-0.000597...   56 75 7   PZ     True
# 46  1.5,3.07655e-010,1.62242e-016,-69.5848,-3.0334...  50 63 10   PZ     True
# 47  1.5,3.07655e-010,1.62242e-016,-69.5848,-3.0334...   68 76 7   PZ    False
# 48  1.5,3.07655e-010,1.62242e-016,-69.5848,-3.0334...   74 68 5   PZ    False
# 49  1.5,3.07655e-010,-6.19441e-017,-111.031,-3.057...   58 82 7   PZ    False
# 50  1.5,3.07655e-010,-1.34424e-017,-79.2234,-3.062...   71 76 6   PZ    False
# 51  1.5,3.07655e-010,4.73832e-017,-99.4643,-2.9758...   51 69 7   PZ    False
# 52  1.5,3.07655e-010,-2.78788e-018,-105.247,-2.937...   42 68 9   PZ    False
# 53  1.5,3.07655e-010,-6.19441e-017,-113.922,-3.057...   61 65 6   AS     True
# 54  1.5,3.07655e-010,1.94538e-017,-96.5728,-2.9646...   77 70 6   PZ    False
# 55  1.5,3.07655e-010,-5.42011e-017,-103.32,-3.0579...  47 67 10   PZ     True
# 56  1.5,3.07655e-010,-5.42011e-017,-103.32,-3.0579...   66 71 7   PZ    False
# 57  1.5,3.07655e-010,1.13253e-016,-86.9342,-2.9158...   50 79 5   PZ     True
# 58  1.5,3.07655e-010,-5.42011e-017,-111.994,-3.057...   72 52 6   AS     True
# 59  1.5,3.07655e-010,-1.15225e-016,-119.705,-3.037...   67 55 6   AS    False
# 60  1.5,3.07655e-010,-1.21665e-016,-74.4041,-3.066...   47 66 9   PZ    False
# 61  1.5,3.07655e-010,-1.21665e-016,-74.4041,-3.066...  70 57 10   PZ    False
#
# [62 rows x 9 columns]
